# %% [markdown]
# #Utiliza Pandas para cargar un conjunto de datos de tu preferencia.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# #Utiliza Pandas para cargar un conjunto de datos de tu preferencia.

# %%
# ruta del archivo
mlb_frames = pd.read_csv("D:\D\GEOFISICA_CON_PYTHON\Clases\Clase5\material\mlb_players.csv",sep = ",", header=0)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\EDWARD\AppData\Local\Temp\ipykernel_7180\279737124.py:2: SyntaxWarning: invalid escape sequence '\D'
#   mlb_frames = pd.read_csv("D:\D\GEOFISICA_CON_PYTHON\Clases\Clase5\material\mlb_players.csv",sep = ",", header=0)

# %% [markdown]
# #Muestra las primeras 10 filas y las últimas 10 filas.

# %%
mlb_frames.head(10)
# Out:
#               Name  Team         Position   Height(inches)  Weight(lbs)    Age
# 0    Adam Donachie   BAL          Catcher               74          180  22.99
# 1        Paul Bako   BAL          Catcher               74          215  34.69
# 2  Ramon Hernandez   BAL          Catcher               72          210  30.78
# 3     Kevin Millar   BAL    First Baseman               72          210  35.43
# 4      Chris Gomez   BAL    First Baseman               73          188  35.71
# 5    Brian Roberts   BAL   Second Baseman               69          176  29.39
# 6    Miguel Tejada   BAL        Shortstop               69          209  30.77
# 7      Melvin Mora   BAL    Third Baseman               71          200  35.07
# 8      Aubrey Huff   BAL    Third Baseman               76          231  30.19
# 9       Adam Stern   BAL       Outfielder               71          180  27.05

# %%
mlb_frames.tail(10)
# Out:
#                     Name  Team         Position   Height(inches)  Weight(lbs)  \
# 1024  Jason Isringhausen   STL   Relief Pitcher               75          230
# 1025      Ricardo Rincon   STL   Relief Pitcher               69          190
# 1026       Braden Looper   STL   Relief Pitcher               75          220
# 1027        Randy Flores   STL   Relief Pitcher               72          180
# 1028        Josh Hancock   STL   Relief Pitcher               75          205
# 1029       Brad Thompson   STL   Relief Pitcher               73          190
# 1030       Tyler Johnson   STL   Relief Pitcher               74          180
# 1031      Chris Narveson   STL   Relief Pitcher               75          205
# 1032       Randy Keisler   STL   Relief Pitcher               75          190
# 1033         Josh Kinney   STL   Relief Pitcher               73          195
#
#         Age
# 1024  34.48
# 1025  36.88
# 1026  32.34
# 1027  31.58
# 1028  28.89
# 1029  25.08
# 1030  25.73
# ...

# %% [markdown]
# Identifica los valores faltantes o nulos de cada columna y manéjalos a tu criterio.

# %%
valores_nulos_por_columna = mlb_frames.isnull().sum()
valores_nulos_por_columna
# Out:
# Name               0
#  Team              0
#  Position          0
#  Height(inches)    0
#  Weight(lbs)       0
#  Age               0
# dtype: int64

# %% [markdown]
# Eliminar Nulos

# %%
dataframe_sin_nulos = mlb_frames.dropna()

# %% [markdown]
# Genera una visualización que muestre las principales medidas estadísticas de cada columna

# %%
mlb_frames.columns
# Out:
# Index(['Name', ' Team', ' Position', ' Height(inches)', ' Weight(lbs)',
#        ' Age'],
#       dtype='object')

# %%
percentil_25 = mlb_frames[' Age'].quantile(0.25)
percentil_50 = mlb_frames[' Age'].quantile(0.5)
percentil_75 = mlb_frames[' Age'].quantile(0.75)

# %%
sns.histplot(mlb_frames[' Age'], bins=40,)
media = mlb_frames[' Age'].mean()
plt.axvline(media, color='orange', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(percentil_25, color='r', linestyle='dashed', linewidth=1, label='25th Percentile')
plt.axvline(percentil_50, color='g', linestyle='dashed', linewidth=1, label='50th Percentile (Median)')
plt.axvline(percentil_75, color='b', linestyle='dashed', linewidth=1, label='75th Percentile')
plt.title('Histograma para la Edad')
plt.xlabel("Chupar")
plt.legend()

# %%
sns.kdeplot(mlb_frames[' Age'], fill=True)
# Out:
# <Axes: xlabel=' Age', ylabel='Density'>

# %%
percentil_25 = mlb_frames[' Height(inches)'].quantile(0.25)
percentil_50 = mlb_frames[' Height(inches)'].quantile(0.5)
percentil_75 = mlb_frames[' Height(inches)'].quantile(0.75)
sns.histplot(mlb_frames[' Height(inches)'], bins=20,)
media = mlb_frames[' Height(inches)'].mean()
plt.axvline(media, color='orange', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(percentil_25, color='r', linestyle='dashed', linewidth=1, label='25th Percentile')
plt.axvline(percentil_50, color='g', linestyle='dashed', linewidth=1, label='50th Percentile (Median)')
plt.axvline(percentil_75, color='b', linestyle='dashed', linewidth=1, label='75th Percentile')
plt.title('Histograma para la Altura')
plt.xlabel("Alturar")
plt.legend()

# %% [markdown]
# Diagrama de correlación

# %%
mlb_frames.columns
# Out:
# Index(['Name', ' Team', ' Position', ' Height(inches)', ' Weight(lbs)',
#        ' Age'],
#       dtype='object')

# %%
columnas_interes = [' Age', ' Height(inches)']
matriz_correlacion = mlb_frames[columnas_interes].corr()
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
sns.pairplot(mlb_frames)
plt.figure(figsize=(8, 9))
plt.show()

# %%
sns.jointplot(x=' Age', y=' Height(inches)', data=mlb_frames)
